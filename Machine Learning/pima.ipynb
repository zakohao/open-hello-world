# %%
import numpy as np
import pandas as pd

train=pd.read_csv('d://pysrc/data/pima.csv')
train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
dftrain=train.loc[:,['Glucose','BMI','Outcome']]
display(dftrain)
# Out:
#      Glucose   BMI  Outcome
# 0        148  33.6        1
# 1         85  26.6        0
# 2        183  23.3        1
# 3         89  28.1        0
# 4        137  43.1        1
# ..       ...   ...      ...
# 763      101  32.9        0
# 764      122  36.8        0
# 765      121  26.2        0
# 766      126  30.1        1
# 767       93  30.4        0
#
# [768 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(dftrain['Glucose'][train['Outcome']==0],dftrain['BMI'][train['Outcome']==0],marker='o')
plt.scatter(dftrain['Glucose'][train['Outcome']==1],dftrain['BMI'][train['Outcome']==1],marker='^')
plt.xlabel('glu')
plt.ylabel('bmi')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
dftrain=train.loc[:,['Glucose','BMI','Outcome']]
dftrain1=dftrain.loc[['Outcome']==1,['Glucose','BMI']]
dftrain0=dftrain.loc[['Outcome']==0,['Glucose','BMI']]
np_type1=dftrain1.to_numpy()[:,0:2]
np_type0=dftrain0.to_numpy()[:,0:2]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 dftrain1=dftrain.iat[['Outcome']==1]
#       2 dftrain0=dftrain.iat[['Outcome']==0]
#       3 np_type1=dftrain1.to_numpy()[:,0:2]
#
# File d:\anaconda3\Lib\site-packages\pandas\core\indexing.py:2439, in _ScalarAccessIndexer.__getitem__(self, key)
#    2436     else:
#    2437         raise ValueError("Invalid call for scalar access (getting)!")
# -> 2439 key = self._convert_key(key)
#    2440 return self.obj._get_value(*key, takeable=self._takeable)
#
# File d:\anaconda3\Lib\site-packages\pandas\core\indexing.py:2512, in _iAtIndexer._convert_key(self, key)
#    2510 for i in key:
#    2511     if not is_integer(i):
# -> 2512         raise ValueError("iAt based indexing can only have integer indexers")
#    2513 return key
#
# ValueError: iAt based indexing can only have integer indexers
